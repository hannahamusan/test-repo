# %%
print("welcome to women in AI fellowship")
# Out:
# welcome to women in AI fellowship

# %%
print("Amusan Hannah Oluwaseun")
# Out:
# Amusan Hannah Oluwaseun

# %%
info = '''My name is Hannie

I love learning
I'm learning at Webfala'''

print(info)
# Out:
# My name is Hannie
#
# I love learning
# I'm learning at Webfala

# %%
name = 'Hannah'
print(name)
# Out:
# Hannah

# %%
text = "hello world"

print(text)
print(text.upper())
print(text.lower())
print(text.title())
# Out:
# hello world
# HELLO WORLD
# hello world
# Hello World

# %%
print(text.replace("world", "python"))
print(text.split())
print(text.split())
# Out:
# hello python
# ['hello', 'world']
# ['hello', 'world']

# %%
text = "python"
print(len(text))
# Out:
# 6

# %%
first = "Hello"
second = "python"
print(first + ' ' + second)
print(8+5)
print('8' + '5')
# Out:
# Hello python
# 13
# 85

# %%
text = "python"
print(text[0])
print(

# %%
text = "Fellowship"
print(text[0:6])
print(text[3:6])
print(text[7:])
print(text[:-4])
print(text[-3:-1])
# Out:
# Fellow
# low
# hip
# Fellow
# hi

# %%
x = '6'
y = '10'
print("x,y")
x,y= y,x
print(x,y)
# Out:
# x,y
# 10 6

# %%
x = 5
y = 10
print (x)
print (y)

a = x # a

# %%
text = "Fellowship"
print(text[0:6])
print(text[3:5])
print(text[7:])
print(text[:-4])
# Out:
# Fellow
# lo
# hip
# Fellow

# %%
name = ' Zainab '
name
print(len(name))
print(len(name.strip()))
# Out:
# 8
# 6

# %%
y = 'God is good'
print(y.upper())
print(y.replace("God", "Jesus"))
# Out:
# GOD IS GOOD
# Jesus is good

# %%
print("jemilah's")
# Out:
# jemilah's

# %%
print("He said: \"go away\"")
# Out:
# He said: "go away"

# %%
print("Hello\nWorld")
print("python  Rocks!")
print('python\nRocks!')
print('python\tRocks!')
# Out:
# Hello
# World
# python  Rocks!
# python
# Rocks!
# python	Rocks!

# %%
#using format
name = "Hannah"
age =33
print("My name is {} and Iam {} years." .format(name,age))
# Out:
# My name is Hannah and Iam 33 years.

# %%
print("My name is {0} and Iam {1} years old.".format(name,age))
# Out:
# My name is Hannah and Iam 33 years old.

# %%
print(f"My name is {name} and I am {age} years old.")    #interpolation3rdmethod
# Out:
# My name is Hannah and I am 33 years old.

# %%
ps
